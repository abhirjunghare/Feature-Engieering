# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '1 Cleaning Process.ipynb', 'Data Cleaning python and pandas.ipynb', 'datagy.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv('datagy.csv')

# %%
df
# Out:
#    Unnamed: 0  unnamad:0 Temprature   Humidity
# 0           0          0           1       1.0
# 1           1          1                   NaN
# 2           2          2           3      31.0
# 3           3          3           2      22.0
# 4           4          4           3      33.0
# 5           5          5           1      11.0
# 6           6          6           2      21.0
# 7           7          7         N/a      24.0
# 8           8          8           1      12.0
# 9           9          9          na      32.0

# %%
missing = [' ','NaN','N/a','na']
df = pd.read_csv('datagy.csv', na_values=missing)

# %%
df
# Out:
#    Unnamed: 0  unnamad:0  Temprature   Humidity
# 0           0          0          1.0       1.0
# 1           1          1          NaN       NaN
# 2           2          2          3.0      31.0
# 3           3          3          2.0      22.0
# 4           4          4          3.0      33.0
# 5           5          5          1.0      11.0
# 6           6          6          2.0      21.0
# 7           7          7          NaN      24.0
# 8           8          8          1.0      12.0
# 9           9          9          NaN      32.0

# %%
df.isnull().any()
# Out:
# Unnamed: 0     False
# unnamad:0      False
# Temprature      True
# Humidity        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# unnamad:0      0
# Temprature     3
# Humidity       1
# dtype: int64

# %%
df1 = df.drop(['Unnamed: 0','unnamad:0'],axis = 1)

# %%
df1
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          NaN      24.0
# 8          1.0      12.0
# 9          NaN      32.0

# %%
df1.isnull().any()
# Out:
# Temprature     True
# Humidity       True
# dtype: bool

# %%
sns.heatmap(df.isnull(), yticklabels=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          NaN      24.0
# 8          1.0      12.0
# 9          NaN      32.0

# %%
df1.dropna()
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 8          1.0      12.0

# %%
df1.dropna(how="all")
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          NaN      24.0
# 8          1.0      12.0
# 9          NaN      32.0

# %%
df1
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          NaN      24.0
# 8          1.0      12.0
# 9          NaN      32.0

# %%
df1.fillna(0)
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          0.0       0.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          0.0      24.0
# 8          1.0      12.0
# 9          0.0      32.0

# %%
df1.fillna(method = 'ffill')
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          1.0       1.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          2.0      24.0
# 8          1.0      12.0
# 9          1.0      32.0

# %%
df1.fillna(method= 'bfill')
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          3.0      31.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          1.0      24.0
# 8          1.0      12.0
# 9          NaN      32.0

# %%
df1.interpolate() # val1 , blank , val2 = val1+val2=new_val , new_val/2 = new value
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 1          2.0      16.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 7          1.5      24.0
# 8          1.0      12.0
# 9          1.0      32.0

# %%
da = df1.dropna()

# %%
da
# Out:
#    Temprature   Humidity
# 0          1.0       1.0
# 2          3.0      31.0
# 3          2.0      22.0
# 4          3.0      33.0
# 5          1.0      11.0
# 6          2.0      21.0
# 8          1.0      12.0

# %%
df.fillna({
 'Humidity': 1111 ,
 'Temprature': 1
})
# Out:
#    Unnamed: 0  unnamad:0  Temprature   Humidity
# 0           0          0          1.0       1.0
# 1           1          1          NaN    1111.0
# 2           2          2          3.0      31.0
# 3           3          3          2.0      22.0
# 4           4          4          3.0      33.0
# 5           5          5          1.0      11.0
# 6           6          6          2.0      21.0
# 7           7          7          NaN      24.0
# 8           8          8          1.0      12.0
# 9           9          9          NaN      32.0

# %%
df.fillna({'Temprature': 1})
# Out:
#    Unnamed: 0  unnamad:0  Temprature   Humidity
# 0           0          0          1.0       1.0
# 1           1          1          NaN       NaN
# 2           2          2          3.0      31.0
# 3           3          3          2.0      22.0
# 4           4          4          3.0      33.0
# 5           5          5          1.0      11.0
# 6           6          6          2.0      21.0
# 7           7          7          NaN      24.0
# 8           8          8          1.0      12.0
# 9           9          9          NaN      32.0

# %%
pip install jupyter_contriv_nbextensions
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000017C28FD6DC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/jupyter-contriv-nbextensions/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000017C28FD6F70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/jupyter-contriv-nbextensions/
# ...
